# %%
import covid_daily

# %%
covid_daily.__functions__
# Out:
# ['overview(as_json)', 'data(country, chart, as_json)']

# %%
data = covid_daily.overview()

# %%
data.head()
# Out:
#   Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  \
# 0         World    10169777     94662       502809       2185         5508727
# 1           USA     2617847     21310       128243         91         1082212
# 2        Brazil     1319274      3333        57149         46          715905
# 3        Russia      634437      6791         9073        104          399087
# 4         India      548857     19280        16485        382          321766
#
#    NewRecovered  ActiveCases  Serious,Critical  TotCases/1M pop  \
# 0         54179      4158241             57949             1305
# 1           775      1407392             15832             7909
# 2             0       546220              8318             6207
# 3          5735       226277              2300             4347
# 4         11620       210606              8944              398
#
#    Deaths/1M pop  TotalTests  Tests/1M pop  Population  1 Caseevery X ppl  \
# 0             64           0             0           0                  0
# 1            387    32143196         97113   330986397                126
# 2            269     2925935         13766   212545812                161
# 3             62    19044954        130504   145934108                230
# 4             12     8227802          5963  1379863384               2514
#
#    1 Deathevery X ppl  1 Testevery X ppl
# 0                   0                  0
# 1                2581                 10
# 2                3719                 73
# 3               16084                  8
# 4               83704                168

# %%
print(data.head())
# Out:
#   Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  TotalRecovered  \
# 0         World    10169777     94662       502809       2185         5508727
# 1           USA     2617847     21310       128243         91         1082212
# 2        Brazil     1319274      3333        57149         46          715905
# 3        Russia      634437      6791         9073        104          399087
# 4         India      548857     19280        16485        382          321766
#
#    NewRecovered  ActiveCases  Serious,Critical  TotCases/1M pop  \
# 0         54179      4158241             57949             1305
# 1           775      1407392             15832             7909
# 2             0       546220              8318             6207
# 3          5735       226277              2300             4347
# 4         11620       210606              8944              398
#
#    Deaths/1M pop  TotalTests  Tests/1M pop  Population  1 Caseevery X ppl  \
# 0             64           0             0           0                  0
# 1            387    32143196         97113   330986397                126
# 2            269     2925935         13766   212545812                161
# 3             62    19044954        130504   145934108                230
# 4             12     8227802          5963  1379863384               2514
#
#    1 Deathevery X ppl  1 Testevery X ppl
# 0                   0                  0
# 1                2581                 10
# 2                3719                 73
# 3               16084                  8
# 4               83704                168

# %%
data = covid_daily.data(country='spain', chart='total-currently-infected-linear')

# %%
print(data.tail())
# Out:
#             Currently Infected
# Date
# 2020-06-23               68549
# 2020-06-24               68881
# 2020-06-25               69278
# 2020-06-26               69689
# 2020-06-27               70250

# %%
import matplotlib.pyplot as plt

# %%
data.plot()

# %% [markdown]
# ---

# %%
AVAILABLE_CHARTS = [
    'total-currently-infected-linear',
    'deaths-cured-outcome-small',
    'coronavirus-cases-linear',
    'graph-cases-daily',
    'graph-active-cases-total',
    'coronavirus-deaths-linear',
    'graph-deaths-daily',
    'cases-cured-daily',
    'deaths-cured-outcome'
]

# %%
from itertools import product

# %%
pairs = list(product((range(3)), (range(3))))

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
fig, axs = plt.subplots(3, 3, figsize=(20,15))

row = col = 0

for idx, chart in enumerate(AVAILABLE_CHARTS):
    try:
        data = covid_daily.data(country='spain', chart=chart)
        data.plot(ax=axs[pairs[idx]], title=chart)
    except:
        pass

fig.tight_layout()
fig.show()
# plt.savefig('covid-daily-plot.png', dpi=300)
